# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_json('users.json', orient='records')
df = df.sort_values(['workshop_number', 'tg_username'])
df
# Out:
#     task_number        tg_username  workshop_number
# 29            5             Daniil                1
# 14            3           Liehtman                1
# 18            4           Liehtman                1
# 23            5           Liehtman                1
# 8             3        Lightingale                1
# 12            4            Mogbymo                1
# 32            2       Pumpumpwirum                1
# 3             2        RandomDanil                1
# 22            4        RandomDanil                1
# 28            5        RandomDanil                1
# 30            4  Sofya_Ozherelieva                1
# 11            3         StacyGrach                1
# 36            5         StacyGrach                1
# 37            3        VladimirBel                1
# 20            3           aiGoreva                1
# 5             3         aleynikovs                1
# 6             4         aleynikovs                1
# ...

# %%
stats_df = pd.DataFrame()

# %%
stats_df['tasks'] = df.groupby('tg_username')['task_number'].apply(list)
stats_df['count'] = df.groupby('tg_username')['task_number'].count()
stats_df = stats_df.sort_values('count', ascending=False)
stats_df
# Out:
#                              tasks  count
# tg_username
# Oleg_Platonov      [2, 3, 4, 5, 6]      5
# Liehtman                 [3, 4, 5]      3
# rugged_monk              [2, 3, 4]      3
# RandomDanil              [2, 4, 5]      3
# aprotopopov              [1, 2, 4]      3
# veegaaa                     [3, 4]      2
# burnyshev                   [3, 4]      2
# StacyGrach                  [3, 5]      2
# egshes                      [1, 4]      2
# aleynikovs                  [3, 4]      2
# arstep                      [2, 3]      2
# Ann8156712                     [2]      1
# iampolosataya                  [5]      1
# fyzbt                          [2]      1
# gur_yan_off                    [2]      1
# konarkcher                     [4]      1
# ionlas                         [2]      1
# nikitamikhaylov                [4]      1
# valukov_alex                   [5]      1
# elavrukhin                     [3]      1
# bloodsource                    [2]      1
# ...
