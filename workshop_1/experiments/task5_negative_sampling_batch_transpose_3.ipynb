# %% [markdown]
# # Negative sampling
#
# You may have noticed that word2vec is really slow to train. Especially with big (> 50 000) vocabularies. Negative sampling is the solution.
#
# The task is to implement word2vec with negative sampling. In more detail: you should implement two ways of negative sampling.
#
# ## Vanilla negative sampling
#
# This is what was discussed in Stanford lecture. The main idea is in the formula:
#
# $$ L = \log\sigma(u^T_o u_c) + \sum^k_{i=1} \mathbb{E}_{j \sim P(w)}[\log\sigma(-u^T_j, u_c)]$$
#
# Where $\sigma$ - sigmoid function, $u_c$ - central word vector, $u_o$ - context (outside of the window) word vector, $u_j$ - vector or word with index $j$.
#
# The first term calculates the similarity between positive examples (word from one window)
#
# The second term is responsible for negative samples. $k$ is a hyperparameter - the number of negatives to sample.
# $\mathbb{E}_{j \sim P(w)}$
# means that $j$ is distributed accordingly to unigram distribution, but it is better to use $P^{3/4}(w)$ (empirical results) and you can experiment with some other approaches (for example, try to use uniform distribution).
#
# Thus, it is only required to calculate the similarity between positive samples and some other negatives. Not across all the vocabulary.
#
# Useful links:
# 1. [Efficient Estimation of Word Representations in Vector Space](https://arxiv.org/pdf/1301.3781.pdf)
# 1. [Distributed Representations of Words and Phrases and their Compositionality](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf)
#
# ## Batch-transpose trick for negative sampling
#
# But we can do better. Maybe we don't need to compute vectors for negative samples at all, because we already have a batch of training data and (hopefully) examples in the batch are highly decorrelated.
#
# Let's assume we work with Skip-gram model.
#
# Let $S$ be a batch of _L2-normalized_ word vectors `(batch_size, 2*window_size + 1, word_vector_dim)`.
#
# ```python
# x = 0.0
# for batch_idx in range(batch):
#     w = S[batch_idx, :, :]
#     x += np.sum(w.T @ w - 1.)
#
# y = 0.0
# for window_idx in range(window):
#     b = S[:, window_idx, :]
#     y += np.sum(b.T @ b)
#
# loss = -x + y```
#
# Think about this loss and compare it to vanilla negative sampling.
#
# Implement word2vec with batch-transpose trick. Modify the formula, if needed.
#
# If you are interested: [more info](https://www.tensorflow.org/extras/candidate_sampling.pdf) on other methods of candidate sampling.
#
# **Results of this task** are the very same as in task 3, **plus**:
#  * implement two models (one with vanilla negative sampling and the other with batch-transpose trick)
#  * compare all of the models from tasks 3-5. In terms of time and number of iterations until convergence and the quality of the resulting vectors.
#  * answer the questions
#
# ### Questions:
# 1. Explain the batch-transpose trick formula in your own words. How would you name x, y, w and b?
# 1. Should it be modified to serve as a word2vec loss? If yes, how?
# 1. Is it possible to do the same trick with CBOW model? If yes, how?
# 1. Does it matter how the batch is made in the case of batch-transpose trick? In the case of vanilla negative sampling?

# %% [markdown]
# **Note**
# Original formula has typos and after discussing with the teacher, original formula is the following:
# ```python
# x = 0.0
# for batch_idx in range(batch):
#     w = S[batch_idx, :, :]
#     x += np.sum(w @ w.T - 1.)
#
# y = 0.0
# for window_idx in range(window):
#     b = S[:, window_idx, :]
#     y += np.sum(b @ b.T)
#
# loss = -x + y```

# %% [markdown]
# ## Answers:
#   1. The purpose of batch-transpose trick is to speed up the training by generating positive and negative pairs "center word - context word" from the same batch without sampling from the whole vocabulary and implementing the algorithm using matrix operations that are computationally efficient (including for running on GPU).
#      - w: dot product of all the rows (word vectors) for specific window from a batch, these vectors are word vectors for center and context words.
#      - b: dot product of all the rows (word vectors) for specific position in window along the batch dimension, these vectors are used as negative contexts.
#      - x: sum of all dot products (similarities) for all center and contexts words in a batch
#      - y: sum of all dot products (similarities) for all vector pairs along batch dimension
#      - loss: value to minimize, equal to maximization of the difference of dot products (similarities) between positive pairs and negative pairs
#
#
#   2. I suppose that original formula is not exactly skipgram model, because:
#       - We have dot products not only between center and all context words, but between all words (including dot product of the word vector itself), so center and context words are equal in this implementation (and it is not equal for skipgram)
#       - If subtraction of 1 is assumed after dot product, it is not obvious what is the purpose of it, because it will be equal to subtracting of batch_size value from x (after processing of all the windows in batch)
#       - It is not obvious why do we need L2-normalized vectors, because similarity calculations for another implementations don't require this normalization, and the have pretty good quality of the words after training. During experiments, it turns out that L2-normalization makes the words' quality worse, so this normalization was excluded from the final implementation
#       - Formula for negative samples generation doesn't control the number of the negative samples for each positive pair
#       - Loss value is different from skipgram, there are no logsigmoid transformations
#
#
#    - Therefore the following changes were performed to make the algorithm to be closer to skipgram implementation:
#       - For positive pairs, generate only pairs "center word - context word"
#       - For negative pairs, generate neg_count negative samples for center word and context words in batch dimension which corresponds to center word index
#       - Subtracting 1 from dot product is removed from implementation.
#       - L2-normalization is removed from implementation, and weight normalization is added.
#       - Dot products are summed after adding logsigmoid transformations for all pairs (positive and negative)
#
#
#   3. _
#   4. Shuffling for this implementation is much more critical comparing to vanilla negative sampling, because we need low correlation between different windows in the same batch for better quality of the negative samples

# %%
from pathlib import Path
from collections import Counter
from itertools import islice, product, chain
from argparse import Namespace

from tqdm import tqdm_notebook

import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from tensorboardX import SummaryWriter
from annoy import AnnoyIndex

from sklearn.decomposition import PCA
from MulticoreTSNE import MulticoreTSNE as TSNE
from umap import UMAP
from adjustText import adjust_text

# %%
DATA_PATH = Path('../data')
MODELS_PATH = Path('../models')

# %% [markdown]
# This is an implementation of Skip-Gram batch-transpose trick, and update all vectors from the same window simultaneously, so all pairs center-context from the same window are in the same batch. This implementation uses PyTorch layers and custom computations.

# %% [markdown]
# ### Preparing for training

# %% [markdown]
# **Creating the batcher**
# Features:
# - Output values are PyTorch tensors
# - Element of batch is window, not pair center-context
# - Shuffle is used for generating less correlated windows in the same batch

# %%
class SkipGramBatcher():
    def __init__(self, text):
        self.text = text
    
    @classmethod
    def from_file(cls, file_path):
        with open(file_path) as f:
            text = f.read()
        
        return cls(text)
    
    def _tokenize(self):
        self.tokens = self.text.split()
    
    def _count_tokens(self):
        self.token_counts = Counter(self.tokens)
    
    def _build_vocab(self, cutoff):
        self.token_counts = dict(filter(lambda x: x[1] >= cutoff, self.token_counts.items()))
        self.token_to_idx = {token:idx for (idx, (token, _)) 
                             in enumerate(self.token_counts.items())}
        self.idx_to_token = {idx:token for (token, idx) in self.token_to_idx.items()}
        self.vocab = set(self.token_to_idx)
        self.vocab_size = len(self.vocab)

    def _filter_tokens(self):
        self.tokens = [token for token in self.tokens if token in self.vocab]
        self.tokens_size = len(self.tokens)
    
    def _vectorize_tokens(self):
        self.vectorized_tokens = [self.token_to_idx[token] for token in self.tokens]
        

    def _create_sliding_window(self, window_size):
        tokens_idx = list(range(window_size, self.tokens_size - window_size))
        np.random.shuffle(tokens_idx)
                      
        for i in tokens_idx: 
            window = self.vectorized_tokens[i - window_size: i + window_size + 1]
            yield window
    
    def devectorize_tokens(self, indices):
        return [self.idx_to_token[idx] for idx in indices]
        
    def prepare_data(self, cutoff=1):
        self._tokenize()
        self._count_tokens()
        self._build_vocab(cutoff)
        self._filter_tokens()
        self._vectorize_tokens()
        
    def generate_batches(self, window_size=1, batch_size=1, drop_last=True):
        window = self._create_sliding_window(window_size)
        batch = list(islice(window, batch_size))
    
        if drop_last:
            while batch and len(batch) == batch_size:
                batch = torch.tensor(batch)
                yield batch
                batch = list(islice(window, batch_size))
        else:
            while batch:
                batch = torch.tensor(batch)
                yield batch
                batch = list(islice(window, batch_size))

# %% [markdown]
# Creating classifier for training word embeddings with the following properties:
# - NaiveWord2VecClassifier
#     - Implemented using PyTorch Embedding layer (for center and context words) and custom operations
#     - Bias is not trained for training all parameters in matrix
#     - Weight normalization for word vectors is used (see paper - https://arxiv.org/abs/1602.07868)
#     - During forward pass, batches of input data are used to generate dot products for positive and negative pairs
#     - Negative pairs are generate as true center word and sampled negative contexts from the batch dimension corresponding to the center word index

# %%
class NaiveWord2VecClassifier(nn.Module):
    def __init__(self, vocabulary_size, embedding_size, neg_count=3):
        super().__init__()
        self.neg_count = neg_count
        self.embedding = nn.utils.weight_norm(nn.Embedding(num_embeddings=vocabulary_size,
                                      embedding_dim=embedding_size), dim=1)
        
    def forward(self, x_in):
        # emb(b, 2*w + 1) = (b, 2*w + 1, d)
        W = self.embedding(x_in)        
#         W_norm = torch.norm(W, dim=2, keepdim=True)
#         W = W / W_norm
        
        center_idx = (W.shape[1] // 2)
        
        # (b, d)
        center_words = W[:, center_idx, :]
        
        # (b, 1, d)
        center_words = center_words.unsqueeze(1)
        
        # (2*w + 1, )
        context_mask = torch.ones(W.shape[1])
        context_mask = context_mask.type(torch.ByteTensor)
        context_mask[center_idx] = 0
        
        # (b, 2*w, d)
        pos_contexts = W[:, context_mask, :]
        
        # (b, 1, 2*w)
        pos_dots = torch.bmm(center_words, pos_contexts.transpose(1, 2))
        
        # (b, d)
        neg_contexts = W[:, center_idx, :]
        
        # (b, 2*w*k)
        neg_idx = torch.randint(neg_contexts.shape[0], size = (W.shape[0], 2 * args.window_size * self.neg_count))
        
        # (b, k, d)
        neg_samples = neg_contexts[neg_idx]
        
        # (b, 1, k)
        neg_dots = torch.bmm(center_words, neg_samples.transpose(1, 2))
        
        x_out = pos_dots
        y_out = neg_dots
        
        return x_out, y_out

# %% [markdown]
# Setting all possible random states to fixed number

# %%
def set_seeds(seed):
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

# %% [markdown]
# Create namespace with all parameters for training (specified values were used for the final model)

# %%
args = Namespace(
    file_path = DATA_PATH/'text8',
    model_state_path = MODELS_PATH/'naive_word2vec_embeddings.pth',
    weights_path = MODELS_PATH/'weights.npz',
    
    embedding_size = 100,
    cutoff = 10,
    window_size = 3,
    neg_count = 5,
    
    seed = 42,
    
    num_epochs = 3,
    batch_size = 1024,
    learning_rate = 0.03,
    iterations = 1000,
    save_iterations = 1e8,
    early_stopping_criteria = 1e8,
    factor=0.5,
    patience=5000,
    
    cuda=True
)

# %% [markdown]
# Create functions for creating and updating necessary parameters while training

# %%
def make_train_state(args):
    return {'stop_early': False,
            'early_stopping_step': 0,
            'early_stopping_best_val': 1e8,
            'learning_rate': [], 
            'epoch_idx': 0,
            'batch_idx': 0,
            'loss': [],
            'model_file_name': args.model_state_path}

def update_train_state(args, model, train_state):
    if train_state['batch_idx'] == 0:
        train_state['stop_early'] = False
        torch.save(model.state_dict(), train_state['model_file_name'])
    else:
        loss = train_state['loss'][-1]

        if loss < train_state['early_stopping_best_val']:
            train_state['early_stopping_best_val'] = loss
            train_state['early_stopping_step'] = 0
            
            if train_state['batch_idx'] % args.save_iterations == 0:
                torch.save(model.state_dict(), train_state['model_file_name'])
        else:
            train_state['early_stopping_step'] += 1 
    
        train_state['stop_early'] = train_state['early_stopping_step'] >= args.early_stopping_criteria
    return train_state

# %% [markdown]
# Check if we can use GPU or CPU
# - GPU was used to train NN, now CUDA is false for saving resources

# %%
if not torch.cuda.is_available():
    args.cuda=False
    
print(f'Using CUDA: {args.cuda}')
args.device = torch.device('cuda' if args.cuda else 'cpu')
# Out:
# Using CUDA: True

# %% [markdown]
# Create batcher, prepare data, and calculate vocabulary size
# - All tokens with frequency less than cuttoff were removed from vocabulary and text, for this implementation cutoff=10 to have vocabulary with size about 50000 tokens
# - Get probabilites for negative sampling, for using during classification stage

# %%
sg_batcher = SkipGramBatcher.from_file(args.file_path)
sg_batcher.prepare_data(cutoff=args.cutoff)

vocabulary_size = len(sg_batcher.vocab)
vocabulary_size
# Out:
# 47134

# %% [markdown]
# ### Main Training Cycle
#
# - 3 epochs were used for training
# - Learning rate scheduler is used to decrease learning rate while loss is not decreasing for specific number of iterations (was not used in current implementation)
# - Monitoring training progress using tqdm_notebook (not displayed because of restarting notebook after training and saving all necessary information to files)
# - Tracking train state for using early stopping and saving intermediate models in file (early stopping is not used in final model)
# - Cumulative moving average is used for tracking loss
#
# There are about 16.5 millions tokens in preprocessed text, so with window_size=3 and vocabulary=47134 there are about 99 millions pairs are used in training (1 epoch)
# Total training time is about 14 minutes on GPU P4 on Google Cloud Platform (about 19 batches per second with batch_size=1024 windows)

# %%
set_seeds(args.seed)

classifier = NaiveWord2VecClassifier(vocabulary_size=vocabulary_size,
                                     embedding_size=args.embedding_size,
                                     neg_count=args.neg_count)
classifier = classifier.to(args.device)

optimizer = optim.Adam(params=classifier.parameters(),
                      lr=args.learning_rate)

epoch_size = (len(sg_batcher.tokens) - (2 * args.window_size)) // args.batch_size

scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer,
                                                 mode='min',
                                                 factor=args.factor,
                                                 patience=args.patience)

epoch_bar = tqdm_notebook(desc='Epochs', 
                          total=args.num_epochs,
                          position=1)

train_bar = tqdm_notebook(desc='Training',
                          position=1,
                          total=epoch_size)


train_state = make_train_state(args)

writer = SummaryWriter(log_dir='logs/task_5', comment='embedding_training')

running_loss = 0.
classifier.train()
iter_idx = 1

try:
    for epoch_index in range(1, args.num_epochs + 1):
        train_state['epoch_index'] = epoch_index
        
        batch_generator = sg_batcher.generate_batches(window_size=args.window_size, 
                                                      batch_size=args.batch_size)

        for batch_idx, batch in enumerate(batch_generator, 1):
            batch = batch.to(args.device)

            optimizer.zero_grad()

            x_out, y_out = classifier(x_in=batch)

            loss = -torch.sum(F.logsigmoid(x_out)) - torch.sum(F.logsigmoid(-y_out))

            loss = loss / args.batch_size
            loss_value = loss.item()
            running_loss += (loss_value - running_loss) / (iter_idx)
            loss.backward()

            learning_rate = optimizer.param_groups[0]['lr']

            train_state['batch_idx'] = batch_idx
            train_state['loss'].append(running_loss)
            train_state['learning_rate'].append(learning_rate)

            train_state = update_train_state(args=args,
                                             model=classifier,
                                             train_state=train_state)

            train_params = dict(loss=running_loss,
                                lr=learning_rate,
                                early_step=train_state['early_stopping_step'],
                                early_best=train_state['early_stopping_best_val'])
            train_bar.set_postfix(train_params)
            train_bar.update()

            optimizer.step()
            scheduler.step(train_state['loss'][-1])
            
            iter_idx += 1

            if train_state['stop_early']:
                break
        
        train_bar.n = 0
        epoch_bar.update()
        
    torch.save(classifier.state_dict(), str(train_state['model_file_name']) + '_last')
except KeyboardInterrupt:
    print('Exit training')
# Out:
# HBox(children=(IntProgress(value=0, description='Epochs', max=3, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Training', max=16172, style=ProgressStyle(description_width='…

# %% [markdown]
# ### Visualizing of the training process results

# %% [markdown]
# Loss values

# %%
train_state_df = pd.DataFrame(train_state)
train_state_df['loss'].plot()
plt.show()

# %% [markdown]
# Learning rate values

# %%
train_state_df['learning_rate'].plot()
plt.show()

# %% [markdown]
# Get matrices with word vectors, calculate average matrix, and save all theses matrices to file
# (Commented because it was used right after training)

# %%
W = classifier.embedding.weight.detach().cpu().numpy()

np.savez(args.weights_path, W=W)

# %% [markdown]
# Preparing words for visualizing and intrinsic evaluation (word analogies and closest vectors)

# %%
words = []
words.extend(['man', 'he', 'woman', 'she'])
words.extend(['fly', 'plane', 'aircraft', 'sail', 'ship', 'ships', 'circle'])
words.extend(['kitten', 'cat', 'puppy', 'dog'])
words.extend(['leg', 'legs', 'hand', 'hands'])
words.extend(['blue', 'color', 'dog', 'breed'])
words.extend(['toe', 'finger', 'foot', 'hand', 'arm'])
words.extend(['talk', 'communicate', 'read', 'interpret'])
words.extend(['man', 'king', 'woman', 'queen', 'doctor'])
words.extend(['man', 'doctor', 'woman', 'nurse'])
words.extend(['fast', 'fastest', 'small', 'smallest', 'rich', 'richest', 'faster', 'stronger'])
words = list(set(words))

# %% [markdown]
# ### Visualizing word vectors

# %% [markdown]
# Load saved weights for exploring final word vectors

# %%
weights = np.load('models_final/task_5_2/weights.npz')
W = weights['W']

# %%
metadata = list(sg_batcher.token_to_idx)

writer = SummaryWriter(log_dir='logs/task_5_2', comment='embedding_training')
writer.add_embedding(W, metadata=metadata, tag='W')

# %% [markdown]
# We can now visualize words cloud in TensorBoard using PCA or TSNE

# %% [markdown]
# <img src="images/task_5/1.PNG" style="height:480px width:640px">

# %% [markdown]
# <img src="images/task_5/2.PNG" style="height:480px width:640px">

# %% [markdown]
# <img src="images/task_5/3.PNG" style="height:480px width:640px">

# %% [markdown]
# <img src="images/task_5/4.PNG" style="height:480px width:640px">

# %% [markdown]
# <img src="images/task_5/5.PNG" style="height:480px width:640px">

# %% [markdown]
# **Conclusion**
# - It seems that word cloud have more homogeneous structures comparing to tasks 3-4 (the reason can't be defined exactly why because we use several new methods for training - negative sampling, shuffling, batch with window elements etc)

# %% [markdown]
# Let's check values in all 3 matrices using heatmaps

# %%
sns.heatmap(W)
plt.show()

# %% [raw]
# sns.heatmap(W_prime)
# plt.show()

# %% [raw]
# sns.heatmap(W_avg)

# %% [markdown]
# **Conclusion**
# - Matrices have some patterns by dimensions (vertical lines)
# - Scale of the values in 2 original matrices have closer values scale comparing to task 3

# %% [markdown]
# Create function to plot word vectors after dimensionality reduction with auto-adjusting of label positions

# %%
def plot_embeddings(embs_reduced, token_to_idx, tokens, fig_size=(12, 12)):
    token_embs = embs_reduced[[token_to_idx[token] for token in tokens]]
    
    fig, ax = plt.subplots(figsize=fig_size)
    ax.scatter(token_embs[:, 0], token_embs[:, 1], alpha=0.3)
    
    texts = [plt.text(token_embs[i, 0], token_embs[i, 1], f'{token}') for i, token in enumerate(tokens)]
    adjust_text(texts)

# %% [markdown]
# Apply PCA and visualize results

# %%
# %%time
pca = PCA(n_components=2, random_state=42)
embs_pca = pca.fit_transform(W)
# Out:
# CPU times: user 360 ms, sys: 4 ms, total: 364 ms
# Wall time: 93.9 ms

# %%
plot_embeddings(embs_pca, sg_batcher.token_to_idx, words, fig_size=(16, 16))

# %% [markdown]
# Apply TSNE and visualize results
# - Multicore version of TSNE is used for speeding up the process (not from sklearn)

# %%
# %%time
tsne = TSNE(n_components=2, n_iter=1000, n_jobs=-1)
embs_tsne = tsne.fit_transform(W)
# Out:
# CPU times: user 23min 17s, sys: 8min 45s, total: 32min 2s
# Wall time: 4min 4s

# %%
plot_embeddings(embs_tsne, sg_batcher.token_to_idx, words, fig_size=(16, 16))

# %% [markdown]
# Apply UMAP and visualize results

# %%
# %%time
umap = UMAP(metric='euclidean')
embs_umap = umap.fit_transform(W)
# Out:
# CPU times: user 1min 41s, sys: 12.5 s, total: 1min 53s
# Wall time: 1min 33s

# %%
plot_embeddings(embs_umap, sg_batcher.token_to_idx, words, fig_size=(16, 16))

# %% [markdown]
# **Conclusion**
# - It seems that TSNE and UMAP are better for visualizing relationships among the words (maybe because this algorithms are non-linear and try to preserve distances or topological structure between points)

# %% [markdown]
# ### Intrinsic evaluation

# %% [markdown]
# Create class for exploring neighbors and word analogies

# %%
class EmbeddingsExplorer():
    def __init__(self, token_to_idx, vectors, metric='euclidean'):
        self.token_to_idx = token_to_idx
        self.idx_to_token = {idx: token for token, idx 
                             in self.token_to_idx.items()}
        self.vectors = vectors
        self.metric = metric
        
        self.index = AnnoyIndex(vectors.shape[1], metric=metric)
        
        print('Building index is started')
        for i in self.token_to_idx.values():
            self.index.add_item(i, self.vectors[i])
        
        self.index.build(50)
        print('Building index is finished')
        
    def get_embedding(self, token):
        return self.vectors[self.token_to_idx[token]]
    
    def get_closest_to_vector(self, vector, n=1):
        nn_indices = self.index.get_nns_by_vector(vector, n)
        return [self.idx_to_token[neighbor] for neighbor in nn_indices]
    
    def compute_closest_tokens(self, target_token, n=1):
        vector = self.get_embedding(target_token)
        closest_tokens = self.get_closest_to_vector(vector, n=n)
        closest_tokens = [token for token in closest_tokens
                          if token != target_token]
        print(f'{target_token}: {closest_tokens}')
    
    def compute_analogy(self, token1, token2, token3, n=30):
        vec1 = self.get_embedding(token1)
        vec2 = self.get_embedding(token2)
        vec3 = self.get_embedding(token3)
        vec4 = vec3 + vec2 - vec1
        
        tokens = set([token1, token2, token3])
        closest_tokens = self.get_closest_to_vector(vec4, n=n)
        closest_tokens = [token for token in closest_tokens
                          if token not in tokens]
        
        if len(closest_tokens) == 0:
            print('Could not find nearest neighbors for the computed vector')
            return
        
        print(f'{token1}:{token2} :: {token3}:{closest_tokens}')

# %% [markdown]
# For evaluation, euclidean metric from Annoy package was used.
# I suppose that norm of the vectors is important feature for this task (more details can be found here - https://stats.stackexchange.com/questions/177905/should-i-normalize-word2vecs-word-vectors-before-using-them)

# %%
emb_explorer = EmbeddingsExplorer(sg_batcher.token_to_idx, W, metric='euclidean')
emb_explorer
# Out:
# Building index is started
# Building index is finished

# %% [markdown]
# **Word Analogies**

# %%
emb_explorer.compute_analogy('man', 'he', 'woman')
# Out:
# man:he :: woman:['she', 'recalled', 'when', 'again', 'was', 'once', 'admitted', 'briefly', 'never', 'thereafter', 'later', 'quietly', 'unhappy', 'him', 'afterwards', 'confessed', 'met', 'had', 'estranged', 'leaving', 'secretly', 'subsequently', 'finally', 'worked', 'raised', 'unexpectedly', 'eventually', 'his', 'apparently']

# %%
emb_explorer.compute_analogy('fly', 'plane', 'sail')
# Out:
# fly:plane :: sail:['circle', 'citadel', 'axis', 'parabola', 'divides', 'crashed', 'then', 'midpoint', 'intersection', 'cabin', 'firth', 'crossing', 'dividing', 'streets', 'direction', 'sailed', 'expedition', 'empty', 'focal', 'liner', 'axes', 'eccentricity', 'crashes', 'lrv', 'nearest', 'galilean', 'heading', 'unnamed']

# %%
emb_explorer.compute_analogy('fly', 'aircraft', 'sail')
# Out:
# fly:aircraft :: sail:['carriers', 'destroyers', 'reconnaissance', 'ships', 'submarines', 'carrier', 'cruise', 'torpedo', 'artillery', 'fleet', 'boats', 'helicopter', 'patrol', 'vehicle', 'sailing', 'ship', 'destroyer', 'tank', 'cruisers', 'battleships', 'cruiser', 'scouting', 'submarine', 'frigate', 'escort', 'aeroplanes', 'infantry', 'amphibious', 'battleship']

# %%
emb_explorer.compute_analogy('kitten', 'cat', 'puppy')
# Out:
# kitten:cat :: puppy:['breed', 'hound', 'dogs', 'hairless', 'breeds', 'eating', 'mixed', 'kangaroo', 'goat', 'rat', 'cats', 'ox', 'koala', 'alpacas', 'soup', 'rabbits', 'varieties', 'camel', 'mold', 'ayahuasca', 'ales', 'maybe', 'literally', 'pickled', 'toasting', 'hungry', 'amerindian', 'resemble']

# %%
emb_explorer.compute_analogy('cat', 'kitten', 'dog')
# Out:
# cat:kitten :: dog:['man', 'girl', 'daredevil', 'lonely', 'bathing', 'snake', 'nude', 'persona', 'stag', 'lovely', 'garfield', 'rabbit', 'weissmuller', 'dresses', 'hairy', 'boss', 'bedroom', 'cloak', 'duet', 'topped', 'lucky', 'humble', 'happy', 'angry', 'monstrous', 'merry', 'dressed', 'cinderella', 'pride']

# %%
emb_explorer.compute_analogy('blue', 'color', 'dog')
# Out:
# blue:color :: dog:['or', 'simply', 'mantra', 'beware', 'polite', 'preferred', 'is', 'a', 'alternatively', 'bad', 'maybe', 'mondegreen', 'convenience', 'whereas', 'blending', 'also', 'similar', 'unique', 'guessing', 'often', 'good', 'like', 'occasionally', 'charm', 'missing', 'called', 'lacking', 'stalking']

# %%
emb_explorer.compute_analogy('toe', 'finger', 'foot')
# Out:
# toe:finger :: foot:['hanging', 'feet', 'bow', 'rider', 'lw', 'archer', 'stone', 'side', 'edge', 'corner', 'shoulder', 'mouth', 'door', 'bottom', 'beside', 'torso', 'lip', 'tattooed', 'floor', 'ceiling', 'spear', 'refectory', 'steed', 'wall', 'dug', 'closes', 'touching', 'chin']

# %%
emb_explorer.compute_analogy('talk', 'communicate', 'read')
# Out:
# talk:communicate :: read:['execute', 'replace', 'translate', 'intended', 'manipulate', 'allowed', 'modify', 'properly', 'modifications', 'secure', 'commands', 'freely', 'to', 'render', 'allow', 'directly', 'carefully', 'isolate', 'extend', 'consecrate', 'trusted', 'conform', 'identify', 'reliably', 'accommodated', 'be', 'accomplish', 'correct']

# %%
emb_explorer.compute_analogy('man', 'king', 'woman')
# Out:
# man:king :: woman:['son', 'abdication', 'henry', 'pretender', 'charlemagne', 'eldest', 'heir', 'sigismund', 'throne', 'iii', 'ethelred', 'queen', 'constantine', 'elder', 'daughter', 'tyre', 'hezekiah', 'matilda', 'aquitaine', 'frederick', 'illegitimate', 'sparta', 'pharaoh', 'macedon', 'crowned', 'prince', 'jeroboam', 'pippin', 'elizabeth']

# %%
emb_explorer.compute_analogy('man', 'doctor', 'woman')
# Out:
# man:doctor :: woman:['child', 'onetime', 'teacher', 'student', 'young', 'herself', 'classmate', 'gentleman', 'mock', 'portraying', 'children', 'tutor', 'montag', 'master', 'bookseller', 'posted', 'orphans', 'rambling', 'contacted', 'quaker', 'genius', 'jolie', 'survivor', 'reporter', 'instructor', 'girl', 's', 'villain']

# %%
emb_explorer.compute_analogy('woman', 'doctor', 'man')
# Out:
# woman:doctor :: man:['kurtz', 'writes', 'wizard', 'gentleman', 'lister', 'entitled', 'quotes', 'narrated', 'mr', 'notices', 'creator', 'savage', 'synopsis', 'protagonist', 'wise', 'maker', 'liar', 'portraying', 'movie', 'dime', 'burger', 'parody', 'mysteries', 'wonder', 'adventures', 'reader', 'utopia', 'master']

# %%
emb_explorer.compute_analogy('right', 'left', 'bottom')
# Out:
# right:left :: bottom:['floor', 'spot', 'crosses', 'inside', 'underneath', 'upwards', 'dumped', 'neck', 'stays', 'pushes', 'blows', 'blowing', 'ceiling', 'onto', 'rolled', 'midday', 'plate', 'drops', 'foot', 'climbs', 'edges', 'wagon', 'pulls', 'folds', 'outwards', 'blown', 'cellar', 'rotates', 'off']

# %%
emb_explorer.compute_analogy('leg', 'legs', 'hand')
# Out:
# leg:legs :: hand:['placing', 'fingers', 'other', 'buttons', 'touch', 'arms', 'torso', 'lights', 'placed', 'individually', 'decks', 'bows', 'horns', 'simultaneously', 'strokes', 'shared', 'lips', 'spots', 'positions', 'with', 'pierced', 'therein', 'tiles', 'daggers', 'swords', 'checkers', 'casts', 'chapels']

# %%
emb_explorer.compute_analogy('fast', 'fastest', 'small')
# Out:
# fast:fastest :: small:['large', 'proportion', 'largest', 'comprised', 'industrialised', 'portion', 'vast', 'growing', 'sizeable', 'sizable', 'substantial', 'poorer', 'seaport', 'area', 'poorest', 'huge', 'populations', 'flourishing', 'margin', 'part', 'principal', 'inhabitants', 'portions', 'remains', 'areas', 'occupies', 'population', 'industrialized', 'picturesque']

# %%
emb_explorer.compute_analogy('large', 'largest', 'old')
# Out:
# large:largest :: old:['oldest', 'slavonic', 'longest', 'testament', 'norse', 'rathaus', 'survives', 'wealthiest', 'name', 'bremen', 'ecclesia', 'parthenon', 'kalevala', 'pictish', 'geneva', 'kyo', 'hou', 'citadel', 'overseer', 'batcave', 'ethiopic', 'jericho', 'exposition', 'sixth', 'apocrypha', 'era', 'phoenician', 'galatian', 'bilingual']

# %%
emb_explorer.compute_analogy('fast', 'faster', 'strong')
# Out:
# fast:faster :: strong:['stronger', 'greater', 'rather', 'weaker', 'broader', 'more', 'relaxed', 'than', 'less', 'much', 'considerably', 'elusive', 'substantially', 'wider', 'deeper', 'somewhat', 'rigid', 'progressively', 'afforded', 'slower', 'longer', 'freer', 'richer', 'compromise', 'tolerances', 'challenging', 'favourable', 'decidedly']

# %% [markdown]
# **Top closest words**

# %%
for word in words:
    emb_explorer.compute_closest_tokens(word, n=10)
# Out:
# puppy: ['laughing', 'hounds', 'rhyme', 'shit', 'fancy', 'koi', 'maybe', 'like', 'goat']
# blue: ['green', 'red', 'yellow', 'white', 'black', 'bright', 'velvet', 'colour', 'colored']
# ships: ['ship', 'sunk', 'sailing', 'submarines', 'carriers', 'boats', 'cruise', 'fleets', 'cruisers']
# circle: ['the', 'sphere', 'traversed', 'triangle', 'radius', 'lens', 'atop', 'whole', 'section']
# richest: ['poorest', 'wealthiest', 'populous', 'cities', 'largest', 'vicinity', 'areas', 'outside', 'region']
# foot: ['bow', 'spot', 'bullet', 'facing', 'bottom', 'finger', 'upwards', 'stick', 'bent']
# arm: ['behind', 'arrow', 'while', 'ground', 'leg', 'foot', 'rear', 'chin', 'onto']
# smallest: ['comprised', 'zeros', 'corresponding', 'represents', 'number', 'counting', 'fraction', 'iteration', 'digits']
# sail: ['vessel', 'ship', 'sailed', 'sailing', 'traveled', 'occupy', 'travel', 'convoy', 'ships']
# small: ['large', 'huge', 'sized', 'tiny', 'scale', 'larger', 'pond', 'smaller', 'disproportionately']
# king: ['iii', 'iv', 'son', 'vii', 'valdemar', 'frederick', 'sigismund', 'prince', 'macedon']
# man: ['woman', 'girl', 'gentleman', 'mysterious', 'lover', 'seeing', 'handsome', 'bride', 'ignorant']
# rich: ['dense', 'like', 'cultured', 'beautiful', 'handsome', 'cultivated', 'diamonds', 'mineral', 'blend']
# she: ['he', 'never', 'her', 'himself', 'finds', 'herself', 'confessed', 'recalled', 'had']
# doctor: ['kurtz', 'onetime', 'gentleman', 'portraying', 'villain', 'master', 'thief', 'hemingway', 'mock']
# finger: ['foot', 'button', 'torso', 'thumb', 'face', 'bow', 'tops', 'bottom', 'stick']
# nurse: ['young', 'tutor', 'fellow', 'prostitute', 'child', 'onetime', 'servant', 'youth', 'gentleman']
# talk: ['show', 'host', 'quiz', 'kids', 'tonight', 'shows', 'viewers', 'watching', 'celebrity']
# breed: ['dog', 'kangaroo', 'breeds', 'horse', 'dogs', 'bird', 'cats', 'llama', 'horses']
# he: ['she', 'himself', 'was', 'never', 'recalled', 'once', 'had', 'him', 'admitted']
# plane: ['axis', 'outer', 'circle', 'thrust', 'axes', 'angle', 'inside', 'challenger', 'cone']
# fly: ['catch', 'shoot', 'lift', 'move', 'ground', 'carry', 'reach', 'sail', 'navigate']
# dog: ['cat', 'wolf', 'goat', 'haired', 'rat', 'lamb', 'deer', 'bee', 'bird']
# communicate: ['help', 'to', 'allowing', 'identify', 'acquire', 'enable', 'express', 'manipulate', 'keep']
# legs: ['hind', 'ears', 'teeth', 'shoulders', 'arms', 'lips', 'nose', 'torso', 'striking']
# fastest: ['biggest', 'supplier', 'sectors', 'worldwide', 'uneven', 'cost', 'dubbed', 'plenty', 'factories']
# hand: ['side', 'on', 'fingers', 'wrist', 'putting', 'discards', 'foot', 'while', 'behind']
# fast: ['quick', 'target', 'medium', 'loading', 'slow', 'quickly', 'safe', 'clutch', 'lightweight']
# read: ['write', 'reader', 'whatever', 'mailer', 'then', 'never', 'will', 'be', 'addressed']
# ship: ['ships', 'sailing', 'warship', 'sunk', 'fleet', 'convoy', 'boat', 'carrying', 'cruise']
# cat: ['dog', 'wolf', 'bird', 'cats', 'breed', 'dogs', 'ox', 'bear', 'bee']
# interpret: ['relate', 'deny', 'compare', 'identify', 'ignore', 'demonstrate', 'according', 'classify', 'adhere']
# queen: ['elizabeth', 'mary', 'princess', 'prince', 'tudor', 'king', 'consort', 'boleyn', 'regent']
# kitten: ['daredevil', 'garfield', 'wedding', 'coffin', 'stranger', 'strange', 'man', 'persona', 'girl']
# aircraft: ['carriers', 'carrier', 'reconnaissance', 'fighter', 'vehicle', 'cruise', 'submarines', 'helicopter', 'missile']
# color: ['colour', 'displays', 'reflective', 'rgb', 'texture', 'screens', 'screen', 'pixels', 'shape']
# toe: ['straight', 'sweep', 'jumps', 'stick', 'slide', 'break', 'neck', 'slip', 'button']
# stronger: ['more', 'less', 'weaker', 'much', 'smaller', 'rather', 'larger', 'better', 'than']
# hands: ['while', 'leaving', 'holding', 'turn', 'putting', 'shaking', 'stripped', 'out', 'eyes']
# woman: ['man', 'child', 'prostitute', 'children', 'gentleman', 'her', 'mortal', 'steals', 'mate']
# faster: ['slower', 'than', 'shorter', 'quicker', 'more', 'less', 'considerably', 'slightly', 'efficient']
# leg: ['pulls', 'nose', 'behind', 'knee', 'wrist', 'shoulder', 'off', 'moves', 'bent']

# %% [markdown]
# **Conclusion**
# - Trained word vectors can capture both several syntactic and semantic relationships, but it seems that this model is a little bit worse on word analogies and nearest neighbors than the model from task 3
